# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1='xyz'
list1 = [i*j for i in s1 for j in range(1,5)]
print(list1)

s2='xyz'
list2 = [i*j for i in range(1,5) for j in s2]
print(list2)

s3=[2,3,4]
list3 = [[i+j] for i in range(3) for j in s3]
print(list3)

s3=[2,3,4]
list3 = [[i+j] for i in range(3) for j in s3]
print(list3)

s4=[2,3,4,5]
list4 = [[i+j for i in range(4)] for j in s4]
print(list4)

list5 = [(j,i) for i in range(1,4) for j in range(1,4)]
print(list5)
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
