# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class parent:
    def input():
        print("Enter length of the sides of triangle: ")
        a=int(input())
        b=int(input())
        c=int(input())
