# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=5
for i in range(n):
    for j in range(i+1):
        print('*',end=" ")
    print("\n")

for i in range(n-1):
    for j in range(n-i-1):
        print('*',end=" ")
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
word=input("Enter word: ")
print("Reverse: ",word[::-1])
# Out:
# Enter word: ineuron
# Reverse:  norueni
